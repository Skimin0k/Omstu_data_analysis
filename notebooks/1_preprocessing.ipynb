# %% [markdown]
# ### Предобработка набора данных "Concrete Compressive Strength"

# %%
import pandas as pd

# %%
data_c = pd.read_excel('../data/concrete_compressive_strength.xls')

# %%
data_c.head(10)
# Out:
#    Cement  Blast Furnace Slag   Fly Ash  Water  Superplasticizer  \
# 0   540.0                  0.0      0.0  162.0               2.5
# 1   540.0                  0.0      0.0  162.0               2.5
# 2   332.5                142.5      0.0  228.0               0.0
# 3   332.5                142.5      0.0  228.0               0.0
# 4   198.6                132.4      0.0  192.0               0.0
# 5   266.0                114.0      0.0  228.0               0.0
# 6   380.0                 95.0      0.0  228.0               0.0
# 7   380.0                 95.0      0.0  228.0               0.0
# 8   266.0                114.0      0.0  228.0               0.0
# 9   475.0                  0.0      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Concrete compressive strength
# 0            1040.0           676.0   28                      79.986111
# 1            1055.0           676.0   28                      61.887366
# ...

# %% [markdown]
# Перекодировать не надо, поскольку все данные числовые

# %%
data_c.isnull().sum()
# Out:
# Cement                           0
# Blast Furnace Slag               0
# Fly Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse Aggregate                 0
# Fine Aggregate                   0
# Age                              0
# Concrete compressive strength    0
# dtype: int64

# %% [markdown]
# В наборе данных отсутствуют пропуски

# %%
data_c.head(10)
# Out:
#    Cement  Blast Furnace Slag   Fly Ash  Water  Superplasticizer  \
# 0   540.0                  0.0      0.0  162.0               2.5
# 1   540.0                  0.0      0.0  162.0               2.5
# 2   332.5                142.5      0.0  228.0               0.0
# 3   332.5                142.5      0.0  228.0               0.0
# 4   198.6                132.4      0.0  192.0               0.0
# 5   266.0                114.0      0.0  228.0               0.0
# 6   380.0                 95.0      0.0  228.0               0.0
# 7   380.0                 95.0      0.0  228.0               0.0
# 8   266.0                114.0      0.0  228.0               0.0
# 9   475.0                  0.0      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Concrete compressive strength
# 0            1040.0           676.0   28                      79.986111
# 1            1055.0           676.0   28                      61.887366
# ...

# %%
# вывод данных в файл
data_c.to_csv('concrete_compressive_strength_preprocessed.csv')

# %% [markdown]
# ### Предобработка набора данных "Качество красного вина"

# %%
data_wine = pd.read_csv('../data/red_wine_quality.csv', delimiter = ';')
data_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Перекодировать нет необходимости, поскольку все значения числовые.

# %%
data_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Пропуски в наборе данных не содержатся

# %%
# вывод данных в файл
data_wine.to_csv('red_wine_quality_preprocessed.csv')
